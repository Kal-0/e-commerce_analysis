# %% [markdown]
# # Gold Layer - [View Name] View
#
# ## Purpose
# [Describe the business purpose of this view. What questions does it answer? What analysis does it enable?]
#
# ## Type
# **SQL View** (lightweight, real-time query)
#
# ## Input
# * **Source:** `[catalog].[schema].[source_table]` ([X] rows)
# * **Source:** `[catalog].[schema].[other_table]` (if applicable)
#
# ## Output
# * **Target:** `[catalog].[schema].vw_[view_name]`
# * **Rows:** [Approximate row count or "Same as source", "Aggregated to X level"]
# * **Refresh:** Real-time (always reflects current source data)
#
# ## Use Cases
# * [Use case 1]
# * [Use case 2]
# * [Use case 3]
#
# ## Why View (not Table)?
# * ✅ [Reason 1 - e.g., "Result is very small"]
# * ✅ [Reason 2 - e.g., "Query is fast"]
# * ✅ [Reason 3 - e.g., "Always synchronized with source"]
# * ✅ Zero storage overhead
#
# ## SQL Logic
# 1. [Step 1 - e.g., "JOIN orders with products"]
# 2. [Step 2 - e.g., "GROUP BY department"]
# 3. [Step 3 - e.g., "Calculate aggregations"]
# 4. [Step 4 - e.g., "ORDER BY relevant column"]
#
# ## Execution
# Run all cells sequentially. Expected runtime: [X] seconds.

# %%
# %sql
-- [View Name] View
-- Purpose: [One-line description]

CREATE OR REPLACE VIEW [catalog].[schema].vw_[view_name] AS
SELECT 
  [column1],
  [column2],
  COUNT([column3]) AS [metric1],
  ROUND(SUM([column4]), 2) AS [metric2],
  ROUND(AVG([column5]), 2) AS [metric3]
FROM [catalog].[schema].[source_table] [alias1]
JOIN [catalog].[schema].[other_table] [alias2] ON [alias1].[key] = [alias2].[key]
WHERE [filter_condition]
GROUP BY [column1], [column2]
ORDER BY [sort_column] DESC;

# %%
# %sql
-- Verify view exists and preview results
-- Add filters or LIMIT clause as appropriate

SELECT * FROM [catalog].[schema].vw_[view_name]
LIMIT 10;
